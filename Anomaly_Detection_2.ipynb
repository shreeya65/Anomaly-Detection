# %%
# !pip install pycaret &> /dev/null
# !pip install sklearn &> /dev/null
# !pip install pandas &> /dev/null

# %%
import pycaret
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
# loading sample dataset from pycaret dataset module
from pycaret.datasets import get_data
data = get_data('anomaly')
# Out:
#        Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 0  0.263995  0.764929  0.138424  0.935242  0.605867  0.518790  0.912225
# 1  0.546092  0.653975  0.065575  0.227772  0.845269  0.837066  0.272379
# 2  0.336714  0.538842  0.192801  0.553563  0.074515  0.332993  0.365792
# 3  0.092108  0.995017  0.014465  0.176371  0.241530  0.514724  0.562208
# 4  0.325261  0.805968  0.957033  0.331665  0.307923  0.355315  0.501899
#
#        Col8      Col9     Col10
# 0  0.608234  0.723782  0.733591
# 1  0.331679  0.429297  0.367422
# 2  0.861309  0.899017  0.088600
# 3  0.158963  0.073715  0.208463
# 4  0.558449  0.885169  0.182754

# %%
# import pycaret anomaly and init setup
from pycaret.anomaly import *
s = setup(data, session_id = 123)
# Out:
# <style type="text/css">
# #T_af170_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_af170" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af170_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_af170_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af170_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af170_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_af170_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af170_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_af170_row1_col1" class="data row1 col1" >(1000, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_af170_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_af170_row2_col1" class="data row2 col1" >(1000, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_af170_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_af170_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_af170_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_af170_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_af170_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_af170_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_af170_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_af170_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_af170_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_af170_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_af170_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_af170_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_af170_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_af170_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_af170_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_af170_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_af170_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_af170_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_af170_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_af170_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_af170_row12_col1" class="data row12 col1" >0e48</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.anomaly import AnomalyExperiment
exp = AnomalyExperiment()

# %%
# init setup on exp
exp.setup(data, session_id = 123)
# Out:
# <style type="text/css">
# #T_18251_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_18251" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18251_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_18251_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18251_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18251_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_18251_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18251_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_18251_row1_col1" class="data row1 col1" >(1000, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18251_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_18251_row2_col1" class="data row2 col1" >(1000, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18251_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_18251_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18251_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_18251_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_18251_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_18251_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_18251_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_18251_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_18251_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_18251_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_18251_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_18251_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_18251_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_18251_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_18251_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_18251_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_18251_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_18251_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_18251_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_18251_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_18251_row12_col1" class="data row12 col1" >893d</td>
#     </tr>
#   </tbody>
# </table>

# %%
available_models=models()

# %%
model_ids = list(available_models.index)

# %%
import pandas as pd
result=[]
for m in model_ids[:-2]:
    model = exp.create_model(m)
    anomalies = exp.assign_model(model)

    # Ensure data is in the correct format before prediction
    if not isinstance(data.columns, pd.RangeIndex):
        data = data.reset_index(drop=True)

    pred = exp.predict_model(model, data=data)
    anomaly_count = pred[pred['Anomaly'] == 1].shape[0]
    filtered_data = pred[pred['Anomaly'] == 0]
    X = filtered_data.drop(columns=['Anomaly', 'Anomaly_Score'], errors='ignore')
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    silhouette_scor=0
    n=0
    for i in range(2,11):
        kmeans = KMeans(n_clusters=i, random_state=123)
        cluster_labels = kmeans.fit_predict(X_scaled)
        silhouette = silhouette_score(X_scaled, cluster_labels)
        if silhouette>silhouette_scor:
            silhouette_scor=silhouette
            n=i
    result.append({"Model": m, "Anomaly_Count": anomaly_count, "Clusters": n, "Silhouette_Score": silhouette_scor})

df = pd.DataFrame(result)
df.to_csv("model_metrics.csv", index=False)
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
